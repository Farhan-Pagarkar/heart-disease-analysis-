# %% [markdown]
# # Varad Tawade | Intern | Hexaware Technologies

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### loading the data and preprocessing it

# %%
df = pd.read_csv('Heart Disease data.csv')
print(df.info())
print(df.isnull().sum())
df.fillna(df.median(), inplace=True)
df['sex'] = df['sex'].map({0: 'Female', 1: 'Male'})
df['cp'] = df['cp'].map({0: 'Mild Pain', 1: 'Unusual Pain', 2: 'Other Pain', 3: 'No Pain'})
df['thal'] = df['thal'].map({1: 'Always Bad', 2: 'Good', 3: 'Sometimes Bad'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# ...

# %% [markdown]
# ### EDA: Exploratory Data Analysis

# %% [markdown]
# ### Basic statistics

# %%
print(df.describe())
# Out:
#                age     trestbps        chol          fbs      restecg  \
# count  1025.000000  1025.000000  1025.00000  1025.000000  1025.000000
# mean     54.434146   131.611707   246.00000     0.149268     0.529756
# std       9.072290    17.516718    51.59251     0.356527     0.527878
# min      29.000000    94.000000   126.00000     0.000000     0.000000
# 25%      48.000000   120.000000   211.00000     0.000000     0.000000
# 50%      56.000000   130.000000   240.00000     0.000000     1.000000
# 75%      61.000000   140.000000   275.00000     0.000000     1.000000
# max      77.000000   200.000000   564.00000     1.000000     2.000000
#
#            thalach        exang      oldpeak        slope           ca  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    149.114146     0.336585     1.071512     1.385366     0.754146
# std      23.005724     0.472772     1.175053     0.617755     1.030798
# ...

# %% [markdown]
# ### 2. Distribution of age, cholesterol, and max heart rate (thalach)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
sns.histplot(df['age'], kde=True, bins=20)
plt.title('Age Distribution')

plt.subplot(1, 3, 2)
sns.histplot(df['chol'], kde=True, bins=20)
plt.title('Cholesterol Distribution')

plt.subplot(1, 3, 3)
sns.histplot(df['thalach'], kde=True, bins=20)
plt.title('Max Heart Rate Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Correlation heatmap using the numeric copy of the dataset

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(10, 8))
# ----> 2 sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt=".2f")
#       3 plt.title('Correlation Heatmap')
#       4 plt.show()
#
# NameError: name 'df_numeric' is not defined

# %% [markdown]
# ### 4. Heart disease prevalence by gender

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='sex', hue='target')
plt.title('Heart Disease by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ### 5. Heart disease prevalence by age group

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[df['target'] == 1]['age'], bins=10, kde=True, color="salmon", label="Could reduce produtions")
sns.histplot(df[df['target'] == 0]['age'], bins=10, kde=True, color="blue", label="Profitability")
plt.title('Sales output')
plt.xlabel('Months')
plt.ylabel('Articulations')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Relationships between key factors and heart disease

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='chol', y='thalach', hue='target', palette='Set1')
plt.title('Cholesterol vs Max Heart Rate by Heart Disease')
plt.xlabel('Cholesterol')
plt.ylabel('Max Heart Rate')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ### 7. Box plot for chest pain type (cp) across heart disease target

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='cp', y='age', hue='target')
plt.title('Age vs Chest Pain Type by Heart Disease')
plt.xlabel('Chest Pain Type')
plt.ylabel('Age')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
